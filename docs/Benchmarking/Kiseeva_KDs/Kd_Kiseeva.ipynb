# %% [markdown]
# # This notebook compares our calculations of Kiseeva KDs to their supporting spreadsheet

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PySulfSat as ss
import Thermobar as pt
pd.options.display.max_columns = None

# %%
Kiseeva_in=pd.read_excel('Kiseeva_Kds.xlsx', sheet_name='PySCSS_testing')

# %%
Calc_Kd=ss.calculate_sulf_kds(Ni_Sulf=Kiseeva_in['Ni_Sulf'],
                                    Cu_Sulf=Kiseeva_in['Cu_Sulf'], 
                                       FeOt_Liq=Kiseeva_in['FeOt_Liq'], 
                                       T_K=Kiseeva_in['T_K'],  
                                       Fe3Fet_Liq=0)

# %%
Calc_Kd.head()
# Out:
#       S_Sulf    O_Sulf    Fe_Sulf  Ni_Sulf  Cu_Sulf           DNi  \
# 0  32.892660  0.732750  31.174590     25.8      9.4   1287.570149
# 1  31.291036  1.784979  44.923985     12.0     10.0   6044.987080
# 2  31.235040  2.562282  60.202677      1.0      5.0   6300.764464
# 3  33.141558  1.398118  59.460324      1.0      5.0  11542.329892
# 4  29.701894  3.498458  60.799648      1.0      5.0   4623.418306
#
#             DCu           DAg         DPb       DZn         DCd        DTl  \
# 0    941.268691   1002.876742   29.231595  0.880007   42.204348   5.739311
# 1   7618.322326   8256.898347   56.145335  0.729398  111.581385   6.339130
# 2   6769.281402   8422.883319   72.591311  1.087713  149.802096   9.931369
# 3  11335.999187  13683.944915  138.878433  1.869396  274.688442  14.760265
# 4   4836.331749   6174.824541   51.330451  0.842830  109.838720   7.854174
#
#         DMn        DIn       DTi       DGa        DSb         DCo        DV  \
# ...

# %%
fig, ((ax0, ax1), (ax2, ax3), (ax4, ax5)) = plt.subplots(3,2, figsize = (10,15)) # adjust dimensions of figure here
ax0.plot([np.min(Kiseeva_in['DNi']), np.max(Kiseeva_in['DNi'])],
        [np.min(Kiseeva_in['DNi']), np.max(Kiseeva_in['DNi'])],
         '-k')
ax0.plot(Kiseeva_in['DNi'], Calc_Kd['DNi'], 'ok', mfc='red')
ax0.set_xlabel('D_Ni Kiseeva Spreadsheet')
ax0.set_ylabel('D_Ni PySCSS')

ax1.plot([np.min(Kiseeva_in['DCu']), np.max(Kiseeva_in['DCu'])],
        [np.min(Kiseeva_in['DCu']), np.max(Kiseeva_in['DCu'])],
         '-k')
ax1.plot(Kiseeva_in['DCu'], Calc_Kd['DCu'], 'ok', mfc='red')
ax1.set_xlabel('D_Cu Kiseeva Spreadsheet')
ax1.set_ylabel('D_Cu PySCSS')

ax2.plot([np.min(Kiseeva_in['DAg']), np.max(Kiseeva_in['DAg'])],
        [np.min(Kiseeva_in['DAg']), np.max(Kiseeva_in['DAg'])],
         '-k')
ax2.plot(Kiseeva_in['DAg'], Calc_Kd['DAg'], 'ok', mfc='red')
ax2.set_xlabel('D_Ag Kiseeva Spreadsheet')
ax2.set_ylabel('D_Ag PySCSS')

ax3.plot([np.min(Kiseeva_in['DPb']), np.max(Kiseeva_in['DPb'])],
        [np.min(Kiseeva_in['DPb']), np.max(Kiseeva_in['DPb'])],
         '-k')
ax3.plot(Kiseeva_in['DPb'], Calc_Kd['DPb'], 'ok', mfc='red')
ax3.set_xlabel('D_Pb Kiseeva Spreadsheet')
ax3.set_ylabel('D_Pb PySCSS')


ax4.plot([np.min(Kiseeva_in['DZn']), np.max(Kiseeva_in['DZn'])],
        [np.min(Kiseeva_in['DZn']), np.max(Kiseeva_in['DZn'])],
         '-k')
ax4.plot(Kiseeva_in['DZn'], Calc_Kd['DZn'], 'ok', mfc='red')
ax4.set_xlabel('D_Zn Kiseeva Spreadsheet')
ax4.set_ylabel('D_Zn PySCSS')

ax5.plot([np.min(Kiseeva_in['DCd']), np.max(Kiseeva_in['DCd'])],
        [np.min(Kiseeva_in['DCd']), np.max(Kiseeva_in['DCd'])],
         '-k')
ax5.plot(Kiseeva_in['DCd'], Calc_Kd['DCd'], 'ok', mfc='red')
ax5.set_xlabel('D_Cd Kiseeva Spreadsheet')
ax5.set_ylabel('D_Cd PySCSS')

fig.tight_layout()

# %%
fig, ((ax0, ax1), (ax2, ax3), (ax4, ax5)) = plt.subplots(3,2, figsize = (10,15)) # adjust dimensions of figure here
ax0.plot([np.min(Kiseeva_in['DTl']), np.max(Kiseeva_in['DTl'])],
        [np.min(Kiseeva_in['DTl']), np.max(Kiseeva_in['DTl'])],
         '-k')
ax0.plot(Kiseeva_in['DTl'], Calc_Kd['DTl'], 'ok', mfc='red')
ax0.set_xlabel('DTl Kiseeva Spreadsheet')
ax0.set_ylabel('DTl PySCSS')

ax1.plot([np.min(Kiseeva_in['DMn']), np.max(Kiseeva_in['DMn'])],
        [np.min(Kiseeva_in['DMn']), np.max(Kiseeva_in['DMn'])],
         '-k')
ax1.plot(Kiseeva_in['DMn'], Calc_Kd['DMn'], 'ok', mfc='red')
ax1.set_xlabel('DMn Kiseeva Spreadsheet')
ax1.set_ylabel('DMn PySCSS')

ax2.plot([np.min(Kiseeva_in['DIn']), np.max(Kiseeva_in['DIn'])],
        [np.min(Kiseeva_in['DIn']), np.max(Kiseeva_in['DIn'])],
         '-k')
ax2.plot(Kiseeva_in['DIn'], Calc_Kd['DIn'], 'ok', mfc='red')
ax2.set_xlabel('DIn Kiseeva Spreadsheet')
ax2.set_ylabel('DIn PySCSS')

ax3.plot([np.min(Kiseeva_in['DTi']), np.max(Kiseeva_in['DTi'])],
        [np.min(Kiseeva_in['DTi']), np.max(Kiseeva_in['DTi'])],
         '-k')
ax3.plot(Kiseeva_in['DTi'], Calc_Kd['DTi'], 'ok', mfc='red')
ax3.set_xlabel('DTi Kiseeva Spreadsheet')
ax3.set_ylabel('DTi PySCSS')


ax4.plot([np.min(Kiseeva_in['DGa']), np.max(Kiseeva_in['DGa'])],
        [np.min(Kiseeva_in['DGa']), np.max(Kiseeva_in['DGa'])],
         '-k')
ax4.plot(Kiseeva_in['DGa'], Calc_Kd['DGa'], 'ok', mfc='red')
ax4.set_xlabel('DGa Kiseeva Spreadsheet')
ax4.set_ylabel('DGa PySCSS')

ax5.plot([np.min(Kiseeva_in['DSb']), np.max(Kiseeva_in['DSb'])],
        [np.min(Kiseeva_in['DSb']), np.max(Kiseeva_in['DSb'])],
         '-k')
ax5.plot(Kiseeva_in['DSb'], Calc_Kd['DSb'], 'ok', mfc='red')
ax5.set_xlabel('DSb Kiseeva Spreadsheet')
ax5.set_ylabel('DSb PySCSS')

fig.tight_layout()

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, figsize = (10,10)) # adjust dimensions of figure here
ax0.plot([np.min(Kiseeva_in['DCo']), np.max(Kiseeva_in['DCo'])],
        [np.min(Kiseeva_in['DCo']), np.max(Kiseeva_in['DCo'])],
         '-k')
ax0.plot(Kiseeva_in['DCo'], Calc_Kd['DCo'], 'ok', mfc='red')
ax0.set_xlabel('DCo Kiseeva Spreadsheet')
ax0.set_ylabel('DCo PySCSS')

ax1.plot([np.min(Kiseeva_in['DV']), np.max(Kiseeva_in['DV'])],
        [np.min(Kiseeva_in['DV']), np.max(Kiseeva_in['DV'])],
         '-k')
ax1.plot(Kiseeva_in['DV'], Calc_Kd['DV'], 'ok', mfc='red')
ax1.set_xlabel('DV Kiseeva Spreadsheet')
ax1.set_ylabel('DV PySCSS')

ax2.plot([np.min(Kiseeva_in['DGe']), np.max(Kiseeva_in['DGe'])],
        [np.min(Kiseeva_in['DGe']), np.max(Kiseeva_in['DGe'])],
         '-k')
ax2.plot(Kiseeva_in['DGe'], Calc_Kd['DGe'], 'ok', mfc='red')
ax2.set_xlabel('DGe Kiseeva Spreadsheet')
ax2.set_ylabel('DGe PySCSS')

ax3.plot([np.min(Kiseeva_in['DCr']), np.max(Kiseeva_in['DCr'])],
        [np.min(Kiseeva_in['DCr']), np.max(Kiseeva_in['DCr'])],
         '-k')
ax3.plot(Kiseeva_in['DCr'], Calc_Kd['DCr'], 'ok', mfc='red')
ax3.set_xlabel('DCr Kiseeva Spreadsheet')
ax3.set_ylabel('DCr PySCSS')




fig.tight_layout()
