# %% [markdown]
# # Correcting SCSS for S$^{6+}$ and SCAS for S$^{2-}$
# - in reality, many magmas contain both S$^{6+}$ and S$^{2-}$ species
# - This means we have to correct the SCSS and SCAS to get the Total dissolved S content before saturation in a S-phase, to compare to say melt inclusion measurements

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PySulfSat as ss
import Thermobar as pt
pd.options.display.max_columns = None

# %% [markdown]
# ## Visualization
# First, lets visualize for a linspace of delta QFM values, how different parameters change, using the S6/St ratios from Jugo et al. (2010)

# %%
SCSS=1000
SCAS=5000
DeltaQFM_lin=np.linspace(-1, 3, 5*10001)
QFM_point1=DeltaQFM_lin==-1
QFM_point2=DeltaQFM_lin==1
QFM_point4=DeltaQFM_lin==2


df_Species=ss.calculate_S_Total_SCSS_SCAS(deltaQFM=DeltaQFM_lin,
            SCSS=SCSS, SCAS=SCAS, model='Jugo')

df_Species.head()
# Out:
#        Total_S  S2_Tot    S6_Tot  deltaQFM     S6_St  SCSS_2  SCAS_6  \
# 0  1000.079433  1000.0  0.079433  -1.00000  0.000079    1000    5000
# 1  1000.079462  1000.0  0.079462  -0.99992  0.000079    1000    5000
# 2  1000.079491  1000.0  0.079491  -0.99984  0.000079    1000    5000
# 3  1000.079521  1000.0  0.079521  -0.99976  0.000080    1000    5000
# 4  1000.079550  1000.0  0.079550  -0.99968  0.000080    1000    5000
#
#       SCSS_Tot      SCAS_Tot  S6 in SCSS_Tot  S2 in SCAS_Tot
# 0  1000.079433  6.295127e+07        0.079433    6.294627e+07
# 1  1000.079462  6.292809e+07        0.079462    6.292309e+07
# 2  1000.079491  6.290491e+07        0.079491    6.289991e+07
# 3  1000.079521  6.288174e+07        0.079521    6.287674e+07
# 4  1000.079550  6.285859e+07        0.079550    6.285359e+07

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4))
SCSS_Tot_excessS6=df_Species['S6 in SCSS_Tot']>df_Species['SCAS_6']

ax1.plot(df_Species['deltaQFM'].loc[~SCSS_Tot_excessS6], df_Species['SCSS_Tot'].loc[~SCSS_Tot_excessS6], '-m', label='SCSS Tot')
ax1.plot(df_Species['deltaQFM'].loc[SCSS_Tot_excessS6], df_Species['SCSS_Tot'].loc[SCSS_Tot_excessS6], ':m')

SCAS_Tot_excessS2=df_Species['S2 in SCAS_Tot']>df_Species['SCSS_2']

ax1.plot(df_Species['deltaQFM'].loc[~SCAS_Tot_excessS2], df_Species['SCAS_Tot'].loc[~SCAS_Tot_excessS2], '-k', label='SCAS_Tot')
ax1.plot(df_Species['deltaQFM'].loc[SCAS_Tot_excessS2], df_Species['SCAS_Tot'].loc[SCAS_Tot_excessS2], ':k')

ax1.plot([-1, 3], [SCSS, SCSS], '-m', lw=0.5, label='S2- sol limit')
ax1.plot([-1, 3], [SCAS, SCAS], '-k', lw=0.5, label='S6 sol limit')
ax1.plot([-1, 3], [SCAS+SCSS, SCAS+SCSS], '-g', lw=0.5, label='ST sol limit')

#ax1.legend()

maxS=SCSS+SCAS
maxX=df_Species['deltaQFM'].loc[df_Species['Total_S']==maxS]
ax2.plot(df_Species['deltaQFM'], df_Species['Total_S'], '-g', lw=2)

# ax2.plot(df_Species['DeltaQFM'].loc[~SCSS_Tot_excessS6], 
#          df_Species['S6 in SCSS_Tot'].loc[~SCSS_Tot_excessS6], '-k')
    
# ax2.plot(df_Species['DeltaQFM'].loc[~SCAS_Tot_excessS2], 
#          df_Species['S2 in SCAS_Tot'].loc[~SCAS_Tot_excessS2], '-m')
     
ax2.yaxis.set_tick_params(which='both', labelbottom=True)
ax2b=ax2.twinx()
ax2.plot(df_Species['deltaQFM'], df_Species['S2_Tot'], '-r', lw=0.5)
ax2.plot(df_Species['deltaQFM'], df_Species['S6_Tot'], '-', color='grey', lw=0.5)

ax2b.plot(df_Species['deltaQFM'], df_Species['S6_St'], '-c')

ax2b.plot([maxX, maxX], [0, 1], ':c')
ax1.set_ylim([0, 10000])
ax2.set_ylim([0, 10000])
ax2b.set_ylim([0, 1])
ax1.set_ylabel('S (ppm)')
ax2.set_ylabel('S (ppm)')
ax1.set_xlabel('ΔQFM')
ax2.set_xlabel('ΔQFM')
ax2b.set_ylabel('S$^{6+}$/S$_{T}$')
fig.tight_layout()
fig.savefig('SCSS_SCAS.png', dpi=300)

# %% [markdown]
# ## Now lets apply it to some Petrolog fractionation path

# %%
df_out=ss.import_data(r'../Intro_Example_Petrolog_FC/PetrologCalculations.xlsx', Petrolog=True)
df_out.head()
# Out:
# We have replaced all missing liquid oxides and strings with zeros.
#    SiO2_Liq  TiO2_Liq  Al2O3_Liq  FeOt_Liq  MnO_Liq  MgO_Liq  CaO_Liq  \
# 0   49.9010    0.9981    14.9715  8.980926   0.0998   9.9763  11.9772
# 1   49.9978    1.0081    15.1220  8.951296   0.1008   9.6064  12.0976
# 2   50.0982    1.0185    15.2770  8.916645   0.1018   9.2279  12.2216
# 3   50.2003    1.0289    15.4337  8.877334   0.1029   8.8486  12.3469
# 4   50.3062    1.0397    15.5950  8.832002   0.1040   8.4612  12.4760
#
#    Na2O_Liq  K2O_Liq  P2O5_Liq  H2O_Liq  Fe3Fet_Liq  Ni_Liq_ppm  Cu_Liq_ppm  \
# 0    2.4953   0.1996    0.0998      0.0    0.098489       697.8        99.8
# 1    2.5203   0.2016    0.1008      0.0    0.097851       624.6       100.7
# 2    2.5462   0.2037    0.1018      0.0    0.097284       554.8       101.6
# 3    2.5723   0.2058    0.1029      0.0    0.096823       489.9       102.6
# 4    2.5992   0.2079    0.1040      0.0    0.096445       428.7       103.5
#
# ...

# %%
Smythe_FixedSulf=ss.calculate_S2017_SCSS(df=df_out,
T_K=df_out['T_K'], P_kbar=df_out['P_kbar'], 
Fe3Fet_Liq=df_out['Fe3Fet_Liq'],
Fe_FeNiCu_Sulf=0.65)
Smythe_FixedSulf.head()
# Out:
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.
# You havent entered a value for Ni_FeNiCu_Sulf and Cu_FeNiCu_Sulf so we cant calculate the non-ideal SCSS
#    SCSS_ideal_ppm_Smythe2017  SCSS_ideal_ppm_Smythe2017_1sigma  T_Input_K  \
# 0                1163.632126                        317.869126   1526.431
# 1                1132.187652                        309.279446   1516.580
# 2                1099.523987                        300.356720   1506.214
# 3                1066.279038                        291.275205   1495.511
# 4                1031.735153                        281.838860   1484.230
#
#    P_Input_kbar  Fe_FeNiCu_Sulf  Fe3Fet_Liq_input  Si_wt_atom  Ti_wt_atom  \
# 0             1            0.65          0.098489    0.458760    0.006900
# 1             1            0.65          0.097851    0.460128    0.006977
# 2             1            0.65          0.097284    0.461540    0.007056
# ...

# %%
ZT22_SCAS=ss.calculate_ZT2022_SCAS(df=df_out, T_K=df_out['T_K'])
ZT22_SCAS.head()
# Out:
#    Calc SCAS (ppm)  SiO2_Liq  TiO2_Liq  Al2O3_Liq  FeOt_Liq  MnO_Liq  MgO_Liq  \
# 0      8797.905353   49.9010    0.9981    14.9715  8.980926        0   9.9763
# 1      8326.386148   49.9978    1.0081    15.1220  8.951296        0   9.6064
# 2      7863.650107   50.0982    1.0185    15.2770  8.916645        0   9.2279
# 3      7418.458243   50.2003    1.0289    15.4337  8.877334        0   8.8486
# 4      6981.487164   50.3062    1.0397    15.5950  8.832002        0   8.4612
#
#    CaO_Liq  Na2O_Liq  K2O_Liq  P2O5_Liq  H2O_Liq  Fe3Fet_Liq  Ni_Liq_ppm  \
# 0  11.9772    2.4953   0.1996    0.0998      0.0    0.098489       697.8
# 1  12.0976    2.5203   0.2016    0.1008      0.0    0.097851       624.6
# 2  12.2216    2.5462   0.2037    0.1018      0.0    0.097284       554.8
# 3  12.3469    2.5723   0.2058    0.1029      0.0    0.096823       489.9
# 4  12.4760    2.5992   0.2079    0.1040      0.0    0.096445       428.7
#
# ...

# %%
df_ST_Nash=ss.calculate_S_Total_SCSS_SCAS(Fe3Fet_Liq=df_out['Fe3Fet_Liq'],
    SCSS=Smythe_FixedSulf['SCSS_ideal_ppm_Smythe2017'],
    T_K=df_out['T_K'],
    SCAS=ZT22_SCAS['Calc SCAS (ppm)'], model='Nash')
df_ST_Nash.head()
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
#        Total_S       S2_Tot     S6_Tot deltaQFM     S6_St       SCSS_2  \
# 0  1181.411865  1163.632126  17.779739     None  0.015050  1163.632126
# 1  1146.119468  1132.187652  13.931816     None  0.012156  1132.187652
# 2  1110.380551  1099.523987  10.856564     None  0.009777  1099.523987
# 3  1074.748164  1066.279038   8.469126     None  0.007880  1066.279038
# 4  1038.301658  1031.735153   6.566504     None  0.006324  1031.735153
#
# ...

# %%
df_ST_FixedS6=ss.calculate_S_Total_SCSS_SCAS(Fe3Fet_Liq=df_out['Fe3Fet_Liq'],
    SCSS=Smythe_FixedSulf['SCSS_ideal_ppm_Smythe2017'],
    T_K=df_out['T_K'],
    SCAS=ZT22_SCAS['Calc SCAS (ppm)'], S6St_Liq=df_ST_Nash['S6_St'])
df_ST_FixedS6.head()
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
#        Total_S       S2_Tot     S6_Tot deltaQFM     S6_St       SCSS_2  \
# 0  1181.411865  1163.632126  17.779739     None  0.015050  1163.632126
# 1  1146.119468  1132.187652  13.931816     None  0.012156  1132.187652
# 2  1110.380551  1099.523987  10.856564     None  0.009777  1099.523987
# 3  1074.748164  1066.279038   8.469126     None  0.007880  1066.279038
# 4  1038.301658  1031.735153   6.566504     None  0.006324  1031.735153
#
# ...

# %%
df_ST_FixedS6=ss.calculate_S_Total_SCSS_SCAS(Fe3Fet_Liq=df_out['Fe3Fet_Liq'],
    SCSS=Smythe_FixedSulf['SCSS_ideal_ppm_Smythe2017'],
    T_K=df_out['T_K'],
    SCAS=ZT22_SCAS['Calc SCAS (ppm)'], S6St_Liq=0.2)
df_ST_FixedS6.head()
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
#        Total_S       S2_Tot      S6_Tot deltaQFM  S6_St       SCSS_2  \
# 0  1454.540158  1163.632126  290.908032     None    0.2  1163.632126
# 1  1415.234565  1132.187652  283.046913     None    0.2  1132.187652
# 2  1374.404984  1099.523987  274.880997     None    0.2  1099.523987
# 3  1332.848797  1066.279038  266.569759     None    0.2  1066.279038
# 4  1289.668942  1031.735153  257.933788     None    0.2  1031.735153
#
# ...

# %%
df_ST_Klein=ss.calculate_S_Total_SCSS_SCAS(
    SCSS=Smythe_FixedSulf['SCSS_ideal_ppm_Smythe2017'],
    T_K=df_out['T_K'], deltaQFM=0.3, 
    SCAS=ZT22_SCAS['Calc SCAS (ppm)'], model='Kleinsasser')
df_ST_Klein.head()
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
# C:\Users\penny\anaconda3\lib\site-packages\pandas\core\indexing.py:2120: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   new_ix = Index(new_ix)
#        Total_S  S2_Tot  S6_Tot  deltaQFM  S6_St       SCSS_2       SCAS_6  \
# 0  1167.760849     NaN     NaN       0.3    NaN  1163.632126  8797.905353
# 1  1136.204806     NaN     NaN       0.3    NaN  1132.187652  8326.386148
# 2  1103.425245     NaN     NaN       0.3    NaN  1099.523987  7863.650107
# 3  1070.062339     NaN     NaN       0.3    NaN  1066.279038  7418.458243
# 4  1035.395888     NaN     NaN       0.3    NaN  1031.735153  6981.487164
#
# ...
