# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:9f6155c4-5ce4-4a22-b189-007a5d810740.png)
# https://link.springer.com/content/pdf/10.1007/s00410-016-1319-8.pdf

# %%
DMg
DOlNi=3.346*DMg -3.665

# %% [markdown]
# ![image.png](attachment:e9dac164-1e82-4fb8-8e18-3e7d087e463e.png)
# ![image.png](attachment:9c54be9c-fc24-4517-8987-50989071675a.png)

# %% [markdown]
# ![image.png](attachment:c4aa0c4d-1498-4079-9bf6-e9b0a742ee47.png)

# %% [markdown]
# ![image.png](attachment:3a9e2669-5206-4dd0-aed1-ddac29c2231d.png)

# %% [markdown]
# ![image.png](attachment:ddd7c1b6-ac99-46ce-96ea-7f5e00dc3e81.png)
# ![image.png](attachment:5b896573-ef4d-463e-82cc-910a29455f51.png)
