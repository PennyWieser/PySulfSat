# %% [markdown]
# 2021 paper: 7.2 coefficient attached to multiplicatoin of Xfe and XSi
# ![image.png](attachment:9716d7f4-2948-459e-8e82-ac28b4db5e7f.png)

# %% [markdown]
# ## In the spreadsheet for 2022, uses 7.2*(XFet+XMn)*XSi
# ![image.png](attachment:13f2595b-5d2f-445d-86b2-7ba0143b29e4.png)
